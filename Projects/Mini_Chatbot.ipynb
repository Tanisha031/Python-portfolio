# %% [markdown]
# # **Mini-Chatbot**

# %%
# Step 1:  Function to get chatbot response

import datetime

def get_response(user_input):
    user_input = user_input.lower()

    # Greetings
    if "hello" in user_input or "hi" in user_input:
        return "Hi there! How can I assist you?"

    # Small talk
    elif "how are you" in user_input:
        return "I'm doing great! How about you?"

    # Bot info
    elif "your name" in user_input:
        return "I'm Chatbot, your virtual assistant."
    elif "what can you do" in user_input:
        return "I can chat with you, tell date and time, or say goodbye."

    # Date and Time
    elif "date" in user_input:
        today = datetime.date.today()
        return f"Today's date is {today.strftime('%B %d, %Y')}."
    elif "time" in user_input:
        now = datetime.datetime.now().strftime("%H:%M:%S")
        return f"Current time is {now}."

    # Goodbye
    elif "bye" in user_input or "exit" in user_input:
        return "Goodbye! Have a wonderful day!"

    # Default response
    else:
        return "I'm not sure how to respond to that, but I'm learning!"

# %%
# Step 2: Main chatbot loop
def chatbot():
    print("Hello! I'm Chatbot. Type 'exit' to end the chat.")
    while True:
        user_input = input("You: ").lower()
        if "exit" in user_input or "bye" in user_input:
            print("Chatbot: Goodbye! Have a great day!")
            break
        response = get_response(user_input)
        print(f"Chatbot: {response}")

if __name__ == "__main__":
    chatbot()
# Out:
# Hello! I'm Chatbot. Type 'exit' to end the chat.
# You: hello
# Chatbot: Hi there! How can I assist you?
# You: How are you?
# Chatbot: I'm doing great! How about you?
# You: I'm good too
# Chatbot: I'm not sure how to respond to that, but I'm learning!
# You: What is your name?
# Chatbot: I'm Chatbot, your virtual assistant.
# You: What is the date today?
# Chatbot: Today's date is November 08, 2025.
# You: What time is it?
# Chatbot: Current time is 09:13:12.
# You: Goodbye
# Chatbot: Goodbye! Have a great day!
