# %% [markdown]
# # **Personal Budget Planner**

# %%
import matplotlib.pyplot as plt
from collections import defaultdict

# Ensure plots appear inline in Colab
# %matplotlib inline

# Step 1: Initialize a list to store expenses
expenses = []

# %%
# Step 2: Set monthly savings goal
def set_savings_goal():
    goal = float(input("Enter your monthly savings goal: "))
    print(f"Your savings goal is set to ${goal:.2f}")
    return goal

# %%
# Step 3: Add income
def add_income():
    income = float(input("Enter your income amount: "))
    print(f"Income of ${income:.2f} added.")
    return income

# %%
# Step 4: Add an expense
def add_expense():
    category = input("Enter expense category (eg, Food, Housing,..): ").capitalize()
    amount = float(input("Enter expense amount: "))
    expenses.append({"category": category, "amount": amount})
    print(f"Expense of ${amount:.2f} added under {category}")

# %%
# Step 5: View expenses by category
def view_expenses_by_category():
    category_totals = defaultdict(float)
    for expense in expenses:
        category_totals[expense["category"]] += expense["amount"]
    print("\nExpenses by Category:")
    for category, total in category_totals.items():
        print(f"{category}: ${total:.2f}")

# %%
# Step 6: Calculate remaining budget
def calculate_remaining_budget(income, expenses):
    total_expenses = sum(expense["amount"] for expense in expenses)
    remaining = income - total_expenses
    print(f"Total Expenses: ${total_expenses:.2f}")
    print(f"Remaining Budget: ${remaining:.2f}")
    return remaining

# %%
# Step 7: Check if savings goal is met
def check_savings_goal(remaining, goal):
    if remaining >= goal:
        print(f"Congratulations! You have met your savings goal with ${remaining - goal:.2f} extra.")
    else:
        print(f"You are ${goal - remaining:.2f} away from your savings goal.")

# %%
def plot_expenses():
    category_totals = defaultdict(float)
    for expense in expenses:
        category_totals[expense["category"]] += expense["amount"]

    labels = list(category_totals.keys())
    sizes = list(category_totals.values())
    plt.figure(figsize=(6,6))
    plt.pie(sizes, labels=labels, autopct="%1.1f%%")
    plt.title("Expense Distribution")
    plt.show(block=False)   # Non-blocking display in Colab
    plt.pause(2)            # Wait 2 seconds to display the chart
    plt.close()             # Close figure so loop continues

# %%
# Step 9: Main program loop
def main():
    print("Welcome to the Personal Budget Planner!")

    # Set goal and income
    goal = set_savings_goal()
    income = add_income()

    # Menu options
    while True:
        print("\nOptions:")
        print("1. Add Expense")
        print("2. View Expenses by Category")
        print("3. Calculate Remaining Budget")
        print("4. Check Savings Goal")
        print("5. Visualize Expenses")
        print("6. Exit")
        choice = input("Enter your choice: ")

        if choice == "1":
            add_expense()
        elif choice == "2":
            view_expenses_by_category()
        elif choice == "3":
            calculate_remaining_budget(income, expenses)
        elif choice == "4":
            remaining = calculate_remaining_budget(income, expenses)
            check_savings_goal(remaining, goal)
        elif choice == "5":
            plot_expenses()
        elif choice == "6":
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

# %%
# Step 10: Run the program
if __name__ == "__main__":
    main()
# Out:
# Welcome to the Personal Budget Planner!
# Enter your monthly savings goal: 700
# Your savings goal is set to $700.00
# Enter your income amount: 8000
# Income of $8000.00 added.
#
# Options:
# 1. Add Expense
# 2. View Expenses by Category
# 3. Calculate Remaining Budget
# 4. Check Savings Goal
# 5. Visualize Expenses
# 6. Exit
# Enter your choice: 1
# Enter expense category (eg, Food, Housing,..): Electric bill
# Enter expense amount: 2000
# Expense of $2000.00 added under Electric bill
#
# Options:
# 1. Add Expense
# 2. View Expenses by Category
# 3. Calculate Remaining Budget
# 4. Check Savings Goal
# 5. Visualize Expenses
# 6. Exit
# Enter your choice: 2
#
# Expenses by Category:
# Food: $500.00
# Housing: $2500.00
# Transport: $2500.00
# Electric bill: $2000.00
#
# Options:
# 1. Add Expense
# 2. View Expenses by Category
# 3. Calculate Remaining Budget
# 4. Check Savings Goal
# 5. Visualize Expenses
# 6. Exit
# Enter your choice: 3
# Total Expenses: $7500.00
# Remaining Budget: $500.00
#
# Options:
# 1. Add Expense
# 2. View Expenses by Category
# 3. Calculate Remaining Budget
# 4. Check Savings Goal
# 5. Visualize Expenses
# 6. Exit
# Enter your choice: 4
# Total Expenses: $7500.00
# Remaining Budget: $500.00
# You are $200.00 away from your savings goal.
#
# Options:
# 1. Add Expense
# 2. View Expenses by Category
# 3. Calculate Remaining Budget
# 4. Check Savings Goal
# 5. Visualize Expenses
# 6. Exit
# Enter your choice: 5
# Options:
# 1. Add Expense
# 2. View Expenses by Category
# 3. Calculate Remaining Budget
# 4. Check Savings Goal
# 5. Visualize Expenses
# 6. Exit
# Enter your choice: 6
# Goodbye!
