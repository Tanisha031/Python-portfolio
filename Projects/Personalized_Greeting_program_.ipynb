# %% [markdown]
# # **Personalized Greeting Program**

# %%
# Step 1: Ask for user details
name = input("What is your name? ")
Lucky_number = int(input("What is your Lucky number are you? "))
color = input("What is your favorite color? ")
# Out:
# What is your name? Elaris
# What is your Lucky number are you? 31
# What is your favorite color? Red

# %%
# Step 2: Generate a personalized greeting message
print("\n---- Personalized Greeting ----")
print(f"Hello, {name}! ")
print(f"You are {Lucky_number} years old and {color} is a beautiful color!")
print("You're now ready to start your Python adventure ")
# Out:
# ---- Personalized Greeting ----
# Hello, Elaris!
# You are 31 years old and Red is a beautiful color!
# You're now ready to start your Python adventure
