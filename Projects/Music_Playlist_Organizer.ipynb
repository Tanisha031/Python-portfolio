# %% [markdown]
# # **Music Playlist Organizer**

# %%
# !pip install mutagen
# Out:
# Requirement already satisfied: mutagen in /usr/local/lib/python3.12/dist-packages (1.47.0)

# %%
# Step 1: Import Required Libraries
import os
import shutil
from mutagen import File
import json

# %%
# Step 2: Scan Directory for Music Files
def scan_directory(directory, extensions=(".mp3", ".flac", ".wav")):
    music_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(extensions):
                music_files.append(os.path.join(root, file))
    return music_files

# %%
# Step 3: Extract Metadata from Music Files
def extract_metadata(file_path):
    try:
        audio = File(file_path, easy=True)
        return {
            "title": audio.get("title", ["Unknown Title"])[0],
            "artist": audio.get("artist", ["Unknown Artist"])[0],
            "album": audio.get("album", ["Unknown Album"])[0],
            "genre": audio.get("genre", ["Unknown Genre"])[0]
        }
    except Exception as e:
        print(f"Error extracting metadata for {file_path}: {e}")
        return None

# %%
# Step 4: Organize Music Files by Artist and Album
def organize_files(music_files, output_directory):
    for file in music_files:
        metadata = extract_metadata(file)
        if metadata:
            artist = metadata["artist"]
            album = metadata["album"]

            artist_folder = os.path.join(output_directory, artist)
            album_folder = os.path.join(artist_folder, album)

            os.makedirs(album_folder, exist_ok=True)
            destination = os.path.join(album_folder, os.path.basename(file))
            shutil.move(file, destination)
            print(f"Moved: {file} -> {destination}")

# %%
# Step 5: Save Summary of Music Files to JSON
def save_summary_to_json(music_files, output_file):
    summary = []
    for file in music_files:
        metadata = extract_metadata(file)
        if metadata:
            summary.append(metadata)

    with open(output_file, "w") as json_file:
        json.dump(summary, json_file, indent=4)
    print(f"Summary saved to {output_file}")

# %%
# Step 6: Main Function
def main():
    print("Welcome to the Music Playlist Organizer!")

    # Input: Music Directory
    music_directory = input("Enter the path to your music directory: ")
    if not os.path.exists(music_directory):
        print("Invalid path. Please try again.")
        return

    # Automatic Output Directory Creation
    output_directory = os.path.join(music_directory, "OrganizedMusic")
    os.makedirs(output_directory, exist_ok=True)
    print(f"Organized music will be stored in: {output_directory}")

    # Scan Music Files
    music_files = scan_directory(music_directory)
    if not music_files:
        print("No music files found.")
        return

    print(f"Found {len(music_files)} music files.")

    # Save JSON Summary
    save_summary_to_json(music_files, os.path.join(output_directory, "music_summary.json"))

    # Organize Files
    organize_files(music_files, output_directory)
    print("Music organization complete!")

# %%
# Step 7: Run the Program
if __name__ == "__main__":
    main()
# Out:
# Welcome to the Music Playlist Organizer!
# Enter the path to your music directory: /content/drive/MyDrive
# Organized music will be stored in: /content/drive/MyDrive/OrganizedMusic
# Found 5 music files.
# Summary saved to /content/drive/MyDrive/OrganizedMusic/music_summary.json
# Moved: /content/drive/MyDrive/ReelAudio-39881.mp3 -> /content/drive/MyDrive/OrganizedMusic/Unknown Artist/Unknown Album/ReelAudio-39881.mp3
# Moved: /content/drive/MyDrive/y2mate.com - Ride It Lyrics  Jay sean  Hindi Version.mp3 -> /content/drive/MyDrive/OrganizedMusic/Unknown Artist/Unknown Album/y2mate.com - Ride It Lyrics  Jay sean  Hindi Version.mp3
# Moved: /content/drive/MyDrive/high_rated_gabru_official_song_directorgifty_t_series_hjWf8A0YNSE.mp3 -> /content/drive/MyDrive/OrganizedMusic/Unknown Artist/Unknown Album/high_rated_gabru_official_song_directorgifty_t_series_hjWf8A0YNSE.mp3
# Moved: /content/drive/MyDrive/Shakira - Waka Waka (This Time for Africa) (The Official 2010 FIFA World Cup Song).mp3 -> /content/drive/MyDrive/OrganizedMusic/Unknown Artist/Unknown Album/Shakira - Waka Waka (This Time for Africa) (The Official 2010 FIFA World Cup Song).mp3
# Moved: /content/drive/MyDrive/BTS, Jungkook - Dreamers (Lyrics) FIFA World Cup 2022 Song.mp3 -> /content/drive/MyDrive/OrganizedMusic/Unknown Artist/Unknown Album/BTS, Jungkook - Dreamers (Lyrics) FIFA World Cup 2022 Song.mp3
# Music organization complete!
