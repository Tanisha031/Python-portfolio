# %%
# Python User input
name = 'Tanisha'
city = 'Chachro'

# %%
# simple python script
print('My name is', name, '&' ,'I live in', city)
# Out:
# My name is Tanisha & I live in Chachro

# %%
#.......input() Function....
name=input()
city=input()
# Out:
# Tanisha
# Hyderabad

# %%
#Prompt input
name=input('Enter your name: ')
city=input('Enter your city: ')
print ("Hello My name is", name)
# Out:
# Enter your name: Kairav
# Enter your city: Islamabd
# Hello My name is Kairav

# %%
#.......raw_input() Function.....

#name=raw_input('Enter my name - ')
#city=raw_input('enter my city name - ')

'''
The raw_input() function works similar to input() function.
Here only point is that this function was available in Python 2.7,
and it has been renamed to input() in Python 3.6
'''
# Out:
# '\nThe raw_input() function works similar to input() function.\nHere only point is that this function was available in Python 2.7,\nand it has been renamed to input() in Python 3.6\n'

# %%
#.......Taking Numeric input.....
'''width = input("Enter width : ")
height = input("Enter height : ")
area = width*height
'''
#This will give give TypeError: can't multiply sequence by non-int of type 'str'. To overcome this problem,
# we shall use int(), another built-in function from Python's standard library.
# It converts a string object to an integer.

# %%
#Example - 01
w = input("Enter width : ")
width = int(w)

h = input("Enter height : ")
height = int(h)
# Out:
# Enter width : 45
# Enter height : 3

# %%
#Example - 02
#You can combine the input and type cast statements in one −
width = int(input("Enter width : "))
height = int(input("Enter height : "))

area = width*height
print ("Area of rectangle = ", area)
# Out:
# Enter width : 45
# Enter height : 3
# Area of rectangle =  135

# %%
#Example -03 using Float built-in function of python.
amount = float(input("Enter Amount : "))
rate = float(input("Enter rate  : "))

interest = amount*rate/100
print ("Amount: ", amount, 'rate: ', rate,"Interest: ", interest)
# Out:
# Enter Amount : 3400
# Enter rate  : 1200
# Amount:  3400.0 rate:  1200.0 Interest:  40800.0

# %%
#The print() Function
print ("Hello World ")
# Out:
# Hello World

# %%
a = 'Tanisha'
b= 31
c = 0.6
d = 2+5j

print('Name : ', a)
print(b , c , ':',b-c)
print(pow(100,0.5),':',pow(c,2))
# Out:
# Name :  Tanisha
# 31 0.6 : 30.4
# 10.0 : 0.36

# %%
#without (Sep= ',')
city="Hyderabad"
state= "Sindh"
country="Pakistan"
print(city, state, country)
# Out:
# Hyderabad Sindh Pakistan

# %%
#with (Sep= ',')
city="Hyderabad"
state="Sindh"
country="Pakistan"
print(city, state, country, sep=',')
# Out:
# Hyderabad,Sindh,Pakistan

# %%
#To make these two lines appear in the same line,
# define end parameter in the first print() function and set it to a whitespace string " ".

city="Hyderabad"
state="Sindh"
country="Pakistan"

print('City:', city, end=' ')
print('State:' , state)
# Out:
# City: Hyderabad State: Sindh
