# %%
#Python Opeerators

# %%
#......Arithmatic Operation......
a =4
b =7
c =0

# %%
c=a+b
print('a:{}, b:{}, a+b:{}'.format(a,b,c))          #Addition
# Out:
# a:20, b:10, a+b:30

# %%
c=a-b
print('a:{}, b:{}, a+b:{}'.format(a,b,c))        #subtraction
# Out:
# a:4, b:7, a+b:-3

# %%
c=a*b
print('a:{}, b:{}, a*b:{}'.format(a,b,c))        #multiplication
# Out:
# a:4, b:7, a*b:28

# %%
c=a/b
print('a:{}, b:{}, a/b:{}'.format(a,b,c))        #division
# Out:
# a:4, b:7, a/b:0.5714285714285714

# %%
c=a%b
print('a:{}, b:{}, a%b:{}'.format(a,b,c))        #modulus
# Out:
# a:4, b:7, a%b:4

# %%
c//b
print('a:{}, b:{}, a//b:{}'.format(a,b,c))        #floor division
# Out:
# a:4, b:7, a//b:4

# %%
c=a**b
print('a:{}, b:{}, a**b:{}'.format(a,b,c))        #exponent
# Out:
# a:4, b:7, a**b:16384

# %%
#.......Comparison Operators.......
a=4
b=7

# %%
if (a==b):                                             #(a == b) is not true.
  print('a is equal to b')
else:
  print('a is not equal to b')
# Out:
# a is not equal to b

# %%
if (a!=b):                                             #(a != b) is true.
  print('a is not equal to b')
else:
  print('a is equal to b')
# Out:
# a is not equal to b

# %%
if (a>b):                                         #(a>b) is not True.
  print('a is greater than b')
else:
  print('a is not greater than b')
# Out:
# a is not greater than b

# %%
if(a<b):
  print('a is less than b')
else:
  print('a is not less tha b')
# Out:
# a is less than b

# %%
if (a>=b):                                        #(a>=b) is not True.
  print('a is greater than or equal to b')
else:
  print('a is not greater than or equal to b')
# Out:
# a is not greater than or equal to b

# %%
if (a<=b):                                        #(a<=b) is true True.
  print('a is less than or equal to b')
else:
  print('a is not less than or equal to b')
# Out:
# a is less than or equal to b

# %%
#......Assignment Operators
a = 4
b = 3
c = 0
print('a:{}, b:{}, c:{}'.format(a,b,c))
# Out:
# a:4, b:3, c:0

# %%
c= a+b
print('a:{}, c=a+b:{}'.format(a,c))     #Addition
# Out:
# a:4, c=a+b:7

# %%
c +=a
print('a:{}, c+=:{}'.format(a,c) )      #
# Out:
# a:4, c+=:11

# %%
c-=a
print ("a: {} c -= a: {}".format(a,c))
# Out:
# a: 4 c -= a: 7

# %%
c *= a
print ("a: {} c *= a: {}".format(a,c))
# Out:
# a: 4 c *= a: 28

# %%
c /= a
print ("a: {} c /= a: {}".format(a,c))
# Out:
# a: 4 c /= a: 7.0

# %%
c=2
print ("a: {} b: {} c : {}".format(a,b,c))
# Out:
# a: 4 b: 3 c : 2

# %%
c %= a
print ("a: {} c %= a: {}".format(a,c))
# Out:
# a: 4 c %= a: 2

# %%
c **= a
print ("a: {} c **= a: {}".format(a,c))
# Out:
# a: 4 c **= a: 16

# %%
c //= a
print ("a: {} c //= a: {}".format(a,c))
# Out:
# a: 4 c //= a: 4

# %%
#......Bitwise Operator......
a = 20
b = 10

# %%
print ('a=',a,':',bin(a),'b=',b,':',bin(b))
# Out:
# a= 20 : 0b10100 b= 10 : 0b1010

# %%
c=0

# %%
c = a&b
print('Result of AND is', c, ':',  bin(c))       #AND
# Out:
# Result of AND is 0 : 0b0

# %%
c = a|b
print('Result of OR is', c, ':',  bin(c))        #OR
# Out:
# Result of OR is 30 : 0b11110

# %%
c = a^b
print('Result of EXOR is', c, ':',  bin(c))      #EXOR
# Out:
# Result of EXOR is 30 : 0b11110

# %%
#c = a ~ b
#print('Result of NOT is', c, ':',  bin(c))      #NOT

#bitwise NOT, apply it to one value only

# %%
#Correct Usage of Bitwise NOT:
#To flip the bits of a number, you apply ~ to a single variable:
c = ~a                                           #NOT
print("~a =", c)
# Out:
# ~a = -21

# %%
c = a<<b
print('Result of Zero fill left shift', c, ':', bin(c))    #Zero fill left shift
# Out:
# Result of Zero fill left shift 20480 : 0b101000000000000

# %%
a>>b
print('Result of Signed right shift',c, ':', bin(c))      #Signed right shift
# Out:
# Result of Signed right shift 20480 : 0b101000000000000

# %%
#.......Logical Operator.....
var = 5

# %%
print(var > 3 and var < 10)          #AND
# Out:
# True

# %%
print(var > 3 or var < 4)            #OR
# Out:
# True

# %%
print(not (var > 3 and var < 10))    #Not
# Out:
# False

# %%
#........Membership Operators.....
a = 10
b=20
list = [1,2,3,4,5]

# %%
print ('a:',a, 'b:',b, 'list:', list)
# Out:
# a: 20 b: 10 list: <class 'list'>

# %%
if a in list:                                              # in
  print('a is available in the given list')
else:
  print('a is not available in the given list')
# Out:
# a is not available in the given list

# %%
if b not in list:
  print('b is not available in the given list')           #not in
else:
  print('b is available in the given list')
# Out:
# b is not available in the given list

# %%
c=b/a
print('c:', c, 'list:', list)
# Out:
# c: 2.0 list: [1, 2, 3, 4, 5]

# %%
if (c in list):
  print('c is available in the given list')
else:
  print('c is not available in the given list')
# Out:
# c is available in the given list

# %%
#.....Identity Operators...

# %%
a = [1, 2, 3, 4, 5]
b = [1, 2, 3, 4, 5]
c = a

# %%
print(a is c,'&',a is b)      # a is b
# Out:
# True & False

# %%
print(a is not c, '&',a is not b)     # a is not b
# Out:
# False & True
