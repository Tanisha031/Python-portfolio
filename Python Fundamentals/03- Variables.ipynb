# %%
# first program
print('hello tanisha')
# Out:
# hello tanisha

# %%
# PI and Gravity value / constants
pi = 3.14
gravity = 9.8
print(pi, gravity)
# Out:
# 3.14 9.8

# %%
# assigning a value to a variable
a = 'apple'
print(a)

# assigning a same value changed value
a = 100
print(a)

# assigning one value to multiple varaibles
a=b=c = 31
print(a,b,c)

# assigning multiple value to multiple variable
a, b, c = 'tanisha', 31, 'BM'
print(a,b,c)
# Out:
# apple
# 100
# 31 31 31
# tanisha 31 BM
