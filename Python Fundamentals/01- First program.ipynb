# %%
print("Hello Tanisha")
# Out:
# Hello Tanisha

# %%
a = 31
b = 4
c = a+b    #Addition
d = a-b    #Subtraction
e = a*b    #Multiplication
f = a/b    #Division
g = a,b = b,a  #Swapped Values
h = a//b      #Integer Division
i = a % b       #Modulus
j = a ** b      #Exponents

# %%
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
print(i)
print(j)
# Out:
# 35
# 27
# 124
# 7.75
# (4, 31)
# 0
# 4
# 4611686018427387904

# %%
name = input("Enter your name:")
print("Hello,", name)
# Out:
# Enter your name:Tanisha
# Hello, Tanisha
