# %% [markdown]
# # **Random Number Generation and Statistics**

# %% [markdown]
# **Numpy Generating Random Number**

# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 59

# %%
# Generate a random float from 0 to 1:
from numpy import random
x = random.rand()
print(x)
# Out:
# 0.9842669862811958

# %%
# Generate a 1-D array containing 5 random integers from 0 to 100:
from numpy import random
x=random.randint(100, size=(5))
print(x)
# Out:
# [80 62 54 32 13]

# %%
# Generate a 2-D array with 3 rows, each row containing 5 random integers from 0 to 100:
from numpy import random
x = random.randint(100, size=(3, 5))
print(x)
# Out:
# [[25 67  6 65 47]
#  [ 7 27 53 94 95]
#  [ 8 88 75 40 77]]

# %%
# Generate a 1-D array containing 5 random floats:
from numpy import random
x = random.rand(5)
print(x)
# Out:
# [0.94905823 0.23105155 0.44960398 0.70363106 0.3593864 ]

# %%
# Generate a 2-D array with 3 rows, each row containing 5 random numbers:
from numpy import random
x = random.rand(3, 5)
print(x)
# Out:
# [[0.99765172 0.7687471  0.34750493 0.50367188 0.13317668]
#  [0.94722927 0.33826109 0.0725966  0.53060531 0.73236489]
#  [0.20923027 0.34673067 0.02329634 0.37292222 0.3825163 ]]

# %%
# Return one of the values in an array:
from numpy import random
x = random.choice([3, 5, 7, 9])
print(x)
# Out:
# 9

# %%
# Generate a 2-D array that consists of the values in the array parameter (3, 5, 7, and 9):
from numpy import random
x = random.choice([3, 5, 7, 9], size=(3, 5))
print(x)
# Out:
# [[7 9 5 7 9]
#  [3 7 7 3 3]
#  [5 3 9 7 9]]

# %%
# numpy.random.randint() function

# importing numpy
import numpy as geek

# output array
out_arr = geek.random.randint(low = 0, high = 3, size = 5)
print ("Output 1D Array filled with random integers : ", out_arr)
# Out:
# Output 1D Array filled with random integers :  [2 1 0 1 0]

# %%
# importing numpy
import numpy as geek


# output array
out_arr = geek.random.randint(low = 4, size =(2, 3))
print ("Output 2D Array filled with random integers : ", out_arr)
# Out:
# Output 2D Array filled with random integers :  [[3 3 0]
#  [1 1 2]]

# %%
# numpy.random.randint() function

# importing numpy
import numpy as geek

# output array
out_arr = geek.random.randint(2, 10, (2, 3, 4))
print ("Output 3D Array filled with random integers : ", out_arr)
# Out:
# Output 3D Array filled with random integers :  [[[6 5 6 6]
#   [3 2 7 9]
#   [8 3 4 5]]
#
#  [[6 2 6 8]
#   [5 4 5 8]
#   [5 4 5 2]]]

# %% [markdown]
# **Random Data Distribution**

# %%
# Generate a 1-D array containing 100 values, where each value has to be 3, 5, 7 or 9.

'''
The probability for the value to be 3 is set to be 0.1
The probability for the value to be 5 is set to be 0.3
The probability for the value to be 7 is set to be 0.6
The probability for the value to be 9 is set to be 0'''

from numpy import random
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))
print(x)
# Out:
# [7 7 5 7 7 5 5 7 7 7 7 7 7 7 7 7 7 5 7 7 5 5 7 7 7 5 7 7 7 7 7 7 7 7 7 3 7
#  7 5 7 7 5 5 7 7 7 7 5 3 7 5 5 5 5 5 5 5 5 7 5 7 7 7 7 7 5 3 5 5 5 5 7 3 3
#  7 7 7 5 5 7 7 7 7 7 3 7 5 7 3 7 5 7 5 7 7 7 7 7 5 7]

# %%
# Same example as above, but return a 2-D array with 3 rows, each containing 5 values.

from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[7 7 7 3 5]
#  [7 7 5 3 5]
#  [3 7 7 7 7]]

# %% [markdown]
# **Numpy** **Arrays** **Permutation**

# %%
# Randomly shuffle elements of following array:

from numpy import random
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
random.shuffle(arr)
print(arr)
# Out:
# [2 4 1 3 5]

# %%
# Generate a random permutation of elements of following array:

from numpy import random
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
print(random.permutation(arr))
# Out:
# [4 5 1 2 3]

# %% [markdown]
# **Seaborn** **Module**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([0, 1, 2, 3, 4, 5])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([0, 1, 2, 3, 4, 5], kind="kde")
plt.show()

# %% [markdown]
# **Numpy** **Normal** **Distribution**

# %%
# Generate a random normal distribution of size 2x3:

from numpy import random
x = random.normal(size=(2, 3))
print(x)
# Out:
# [[ 0.63555062 -0.33596931  0.59104431]
#  [-1.04974458  0.38109937 -0.79041705]]

# %%
# Generate a Single Random Number

import numpy as np
random_number = np.random.normal()
print(random_number)
# Out:
# 1.0840775522561878

# %%
# Generate an Array of Random Numbers

random_numbers = np.random.normal(size=5)
print(random_numbers)
# Out:
# [-0.78422634 -1.48975502  0.80081458 -2.16182547  0.30807766]

# %%
# Generate a random normal distribution of size 2x3 with mean at 1 and standard deviation of 2:

from numpy import random
x = random.normal(loc=1, scale=2, size=(2, 3))
print(x)
# Out:
# [[-0.17863069  1.74399028  2.94183016]
#  [ 2.99848756  2.14955467  2.88646929]]

# %%
# visualize normal distribution

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.normal(size=1000), kind="kde")

plt.show()

# %%
# Visualizing the Normal Distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm  # <-- needed for norm.pdf

# parameters
loc, scale = 0, 1

# random data from N(loc, scale)
data = np.random.normal(loc=loc, scale=scale, size=1000)

# histogram as density
plt.hist(data, bins=30, edgecolor='black', density=True)

# x-grid for smooth PDF curve
x = np.linspace(data.min(), data.max(), 200)

# theoretical PDF of N(loc, scale)
pdf = norm.pdf(x, loc=loc, scale=scale)

# overlay PDF
plt.plot(x, pdf, label='Theoretical PDF')

# labels & legend
plt.title("Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Numpy** **Binomial** **Distribution**

# %%
#  Generate a Single Random Number

import numpy as np
random_number = np.random.binomial(n=10, p=0.5)
print(random_number)
# Out:
# 4

# %%
# Generate an Array of Random Numbers

random_numbers = np.random.binomial(n=10, p=0.5, size=5)
print(random_numbers)
# Out:
# [5 3 3 3 3]

# %%
# Given 10 trials for coin toss generate 10 data points:

from numpy import random
x = random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [2 6 4 4 5 3 5 5 7 6]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.5
size = 1000

data = np.random.binomial(n=n, p=p, size=size)

plt.hist(data, bins=np.arange(-0.5, n+1.5, 1), density=True, edgecolor='black', alpha=0.7, label='Histogram')

x = np.arange(0, n+1)
pmf = binom.pmf(x, n=n, p=p)
plt.scatter(x, pmf, color='red', label='Theoretical PMF')
plt.vlines(x, 0, pmf, colors='red', linestyles='dashed')

plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **Numpy** **Poisson** **Distribution**

# %%
# Generate a Single Random Number

import numpy as np
random_number = np.random.poisson(lam=5)
print(random_number)
# Out:
# 5

# %%
# Generate an Array of Random Numbers

random_numbers = np.random.poisson(lam=5, size=5)
print(random_numbers)
# Out:
# [4 6 3 7 6]

# %%
# Generate a random 1x10 distribution for occurrence 2:

from numpy import random
x = random.poisson(lam=2, size=10)
print(x)
# Out:
# [2 3 3 3 1 2 3 2 3 2]

# %%
# Visualizing the Poisson Distribution

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.poisson(lam=2, size=1000))
plt.show()

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

lam = 2
size = 1000

data = random.poisson(lam=lam, size=size)

sns.displot(data, kde=False, bins=np.arange(-0.5, max(data)+1.5, 1), color='skyblue', edgecolor='black')

plt.title(f"Poisson Distribution (λ={lam})")
plt.xlabel("Number of Events")
plt.ylabel("Frequency")
plt.grid(True)

plt.show()

# %%
# Difference Between Normal and Poisson Distribution


from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

data = {
  "normal": random.normal(loc=50, scale=7, size=1000),
  "poisson": random.poisson(lam=50, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
# Difference Between Binomial and Poisson Distribution

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

data = {
  "binomial": random.binomial(n=1000, p=0.01, size=1000),
  "poisson": random.poisson(lam=10, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %% [markdown]
# **Numpy** **Uniform** **Distribution**

# %%
#  Generate a Single Random Number

import numpy as np
random_number = np.random.uniform()
print(random_number)
# Out:
# 0.9764521591668749

# %%
# To generate multiple random numbers:

random_numbers = np.random.uniform(size=5)
print(random_numbers)
# Out:
# [0.4194193  0.21401054 0.2375891  0.42293639 0.09685239]

# %%
# Create a 2x3 uniform distribution sample:

from numpy import random
x = random.uniform(size=(2, 3))
print(x)
# Out:
# [[0.66262821 0.85865659 0.61841537]
#  [0.32862198 0.97359824 0.96248637]]

# %%
# Visualization of Uniform Distribution

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.uniform(size=1000), kind="kde")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

low = 10
high = 20
size = 1000

data = np.random.uniform(low=low, high=high, size=size)
sns.histplot(data, bins=30, kde=False, color='skyblue', edgecolor='black')

plt.title(f"Uniform Distribution (Range: {low} to {high})")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# **Numpy** **Exponential** **Distribution**

# %%
# Draw out a sample for exponential distribution with 2.0 scale with 2x3 size:

from numpy import random
x = random.exponential(scale=2, size=(2, 3))
print(x)
# Out:
# [[ 1.94638005  0.47327413 13.87157745]
#  [ 0.63559153  4.13479065  0.72293015]]

# %%
#  Generate a Single Random Number

import numpy as np
random_number = np.random.exponential()
print(random_number)
# Out:
# 0.2576701624373541

# %%
# To generate multiple random numbers:

random_numbers = np.random.exponential(size=5)
print(random_numbers)
# Out:
# [0.52770391 0.53671408 1.7987303  0.2756699  0.39404214]

# %%
# Visualization of Exponential Distribution

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.exponential(size=1000), kind="kde")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

scale = 2
size = 1000

data = np.random.exponential(scale=scale, size=size)

sns.histplot(data, bins=30, kde=True, color='purple', edgecolor='black')

plt.title(f"Exponential Distribution (Scale={scale})")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)

plt.show()
